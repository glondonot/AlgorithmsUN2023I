# %% [markdown]
# <a href="https://colab.research.google.com/github/glondonot/AlgorithmsUN2023I/blob/main/Lab3/Glondonot_cognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Glondonot_Python 101 for data science.png](data:image/png;base64,...)

# %% [markdown]
# ![Glondonot_Data analysis with python.png](data:image/png;base64,...)

# %% [markdown]
# ![Glondonot_Data visualization with python.png](data:image/png;base64,...)

# %% [markdown]
# ![Linkedin1.png](data:image/png;base64,...)!

# %% [markdown]
# ![Linkedin2.png](data:image/png;base64,...)
